# %%
#importing the libraries for the processing the data

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import interact,widgets

# %%
#Loading the File
file = pd.read_csv(r"C:\Users\bensu\Downloads\Agriculture_based_data.csv")

# %%
file.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
#checking for Null value in the data
file.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#checking for duplicate value in column

file['temperature'].value_counts()
# Out:
# temperature
# 20.879744    1
# 29.480699    1
# 29.943492    1
# 28.033065    1
# 29.884305    1
#             ..
# 25.365861    1
# 28.568406    1
# 30.284966    1
# 27.325421    1
# 23.603016    1
# Name: count, Length: 2200, dtype: int64

# %%
#Checking the Average Requirement for Soil

print("The Average Ratio of Nitrogen in the Soil is : {0:.2f}".format(file['N'].mean()))
print("The Avergae Ratio of Phosphorus in the Soil is : {0:.2f}".format(file['P'].mean()))
print("The Average Ratio of Potassium in the Soil is : {0:.2f}".format(file['K'].mean()))
print("The Average Temperature in celsius : {0:.2f}".format(file['temperature'].mean()))
print("The Relative Humidity is :{0:.2f} ".format(file['humidity'].mean()))
print("The Average ph of soil value is :{0:.2f}".format(file['ph'].mean()))
print("The Average rainfall is {0:.2f}".format(file['rainfall'].mean()))
# Out:
# The Average Ratio of Nitrogen in the Soil is : 50.55
# The Avergae Ratio of Phosphorus in the Soil is : 53.36
# The Average Ratio of Potassium in the Soil is : 48.15
# The Average Temperature in celsius : 25.62
# The Relative Humidity is :71.48
# The Average ph of soil value is :6.47
# The Average rainfall is 103.46

# %%
#crop requirement
@interact
def summary(crops = list(file['label'].value_counts().index)):
    x = file[file['label'] == crops]
    print("-----------------------------------")
    print("Statistics for Nitrogen")
    print("Minimum Nitrogen required : ",x['N'].min())
    print("Average Nitrogen required : ",x['N'].mean())
    print("Maximum Nitrogen required : ",x['N'].max())
    print("-----------------------------------")
    print("Statistics for Phosphorus")
    print("Minimum Phosphorus required : ",x['P'].min())
    print("Average Phosphorus required : ",x['P'].mean())
    print("Maximum Phosphorus required : ",x['P'].max())
    print("-----------------------------------")
    print("Statistics for Potassium ")
    print("Minimum Potassium required : ",x['K'].min())
    print("Average Potassium required : ",x['K'].mean())
    print("Maximum Potassium required : ",x['K'].max())
    print("-----------------------------------")
    print("Statistics for Temperature ")
    print("Minimum Temperature : {0:.2f}".format(x['temperature'].min()))
    print("Average Temperature : {0:.2f}".format(x['temperature'].mean()))
    print("Maximum Temperature : {0:.2f}".format(x['temperature'].max()))
    print("-----------------------------------")
    print("Statistics for Humidity  ")
    print("Minimum Humidity required : {0:.2f}".format(x['humidity'].min()))
    print("Average Humidity required : {0:.2f}".format(x['humidity'].mean()))
    print("Maximum Humidity required : {0:.2f}".format(x['humidity'].max()))
    print("-----------------------------------")
    print("Statistics for ph   ")
    print("Minimum ph  required : {0:.2f}".format(x['ph'].min()))
    print("Average ph  required : {0:.2f}".format(x['ph'].mean()))
    print("Maximum ph  required : {0:.2f}".format(x['ph'].max()))
    print("-----------------------------------")
    print("Statistics for rainfall    ")
    print("Minimum rainfall required : {0:.2f}".format(x['rainfall'].min()))
    print("Average rainfall required : {0:.2f}".format(x['rainfall'].mean()))
    print("Maximum rainfall required : {0:.2f}".format(x['rainfall'].max()))
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'jute', 'cotton', 'coconut', 'pa…

# %%
#Label from the Data fields
print(file['label'].unique())
# Out:
# ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']

# %%
#Checking diffrent factor for each crop 
@interact
def compare(conditions = ['N','P','K','temperature','humidity','ph','rainfall']):
    print("Average Value for",conditions," is {0:.2f}".format(file[conditions].mean()))
    print("-----------------------------------------------")
    print("Rice :{0:.2f}".format(file[(file['label'] == 'rice')][conditions].mean()))
    print("maize :{0:.2f}".format(file[(file['label'] == 'maize')][conditions].mean()))
    print("chickpea :{0:.2f}".format(file[(file['label'] == 'chickpea')][conditions].mean()))
    print("kidneybeans :{0:.2f}".format(file[(file['label'] == 'kidneybeans')][conditions].mean()))
    print("pigeonpeas :{0:.2f}".format(file[(file['label'] == 'pigeonpeas')][conditions].mean()))
    print("mothbeans :{0:.2f}".format(file[(file['label'] == 'mothbeans')][conditions].mean()))
    print("mungbean :{0:.2f}".format(file[(file['label'] == 'mungbean')][conditions].mean()))
    print("blackgram :{0:.2f}".format(file[(file['label'] == 'blackgram')][conditions].mean()))
    print("lentil :{0:.2f}".format(file[(file['label'] == 'lentil')][conditions].mean()))
    print("pomegranate :{0:.2f}".format(file[(file['label'] == 'pomegranate')][conditions].mean()))
    print("banana :{0:.2f}".format(file[(file['label'] == 'banana')][conditions].mean()))
    print("mango :{0:.2f}".format(file[(file['label'] == 'mango')][conditions].mean()))
    print("grapes :{0:.2f}".format(file[(file['label'] == 'grapes')][conditions].mean()))
    print("watermelon :{0:.2f}".format(file[(file['label'] == 'watermelon')][conditions].mean()))
    print("muskmelon :{0:.2f}".format(file[(file['label'] == 'muskmelon')][conditions].mean()))
    print("apple :{0:.2f}".format(file[(file['label'] == 'apple')][conditions].mean()))
    print("orange :{0:.2f}".format(file[(file['label'] == 'orange')][conditions].mean()))
    print("papaya :{0:.2f}".format(file[(file['label'] == 'papaya')][conditions].mean()))
    print("coconut :{0:.2f}".format(file[(file['label'] == 'coconut')][conditions].mean()))
    print("cotton :{0:.2f}".format(file[(file['label'] == 'cotton')][conditions].mean()))
    print("jute :{0:.2f}".format(file[(file['label'] == 'jute')][conditions].mean()))
    print("coffee :{0:.2f}".format(file[(file['label'] == 'coffee')][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'humidity', 'p…

# %%
#checking the crop with high ussage of Nitrogen,Phosphorus, Potasium, Temrature, Humidity,Ph, Rainfall
@interact
def compare(conditions = ['N','P','K','temperature','humidity','ph','rainfall']):
    print("Crops which requires greater then Average ", conditions,'\n')
    
    print(file[file[conditions] > file[conditions].mean()]['label'].unique())
    print("------------------------------")
    print(file[file[conditions] <= file[conditions].mean()]['label'].unique())
    print("------------------------------")
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'humidity', 'p…

# %% [markdown]
# # Distribution

# %%
# checking the distrbution of diffrent agricultural conditions using Graphs
plt.rcParams['figure.figsize'] = (25,12)

plt.subplot(2,4,1)
sns.distplot(file['N'],color = 'lightgrey')
plt.xlabel('Ratio of Nitrogen', fontsize = 12)
plt.grid()

plt.subplot(2,4,2)
sns.distplot(file['P'],color='darkblue')
plt.xlabel('Ratio of Phosphorus', fontsize = 12)
plt.grid()


plt.subplot(2,4,3)
sns.distplot(file['K'],color= 'skyblue')
plt.xlabel('Ratio of Pottasium', fontsize = 12)
plt.grid()

plt.subplot(2,4,4)
sns.distplot(file['temperature'],color='green')
plt.xlabel('Temperature',fontsize = 12)
plt.grid()

plt.subplot(2,4,5)
sns.distplot(file['humidity'],color='red')
plt.xlabel('Humidity',fontsize = 12)
plt.grid()

plt.subplot(2,4,6)
sns.distplot(file['ph'],color='purple')
plt.xlabel('PH Value', fontsize = 12)
plt.grid()

plt.subplot(2,4,7)
sns.distplot(file['rainfall'],color='cyan')
plt.xlabel('Rainfall',fontsize = 12)
plt.grid()

# %%
#checking diffrent patterns for diffrent crop harvesting

print("Some interesting patterns")
print("-----------------------------------------")
print("Crops Which Requires Very High Ratio of Nitrogen content in Soil:",file[file['N']>120]['label'].unique())
print("Crops Which Requires Very High Ratio of Phosphorus content in Soil:",file[file['P']>100]['label'].unique())
print("Crops Which Requires Very High Ratio of Pottasium content in Soil:",file[file['K']>200]['label'].unique())
print("Crops Which Requires Very High Ratio of Rainfall content in Soil:",file[file['rainfall']>200]['label'].unique())
print("Crops Which Requires Very low Temprature:",file[file['temperature']<10]['label'].unique())
print("Crops Which Requires Very High Temprature:",file[file['temperature']>40]['label'].unique())
print("Crops Which Requires Very low Humidity:",file[file['humidity']<20]['label'].unique())
print("Crops Which Requires Very low PH:",file[file['ph']<4]['label'].unique())
print("Crops Which Requires Very High PH:",file[file['ph']>9]['label'].unique())
# Out:
# Some interesting patterns
# -----------------------------------------
# Crops Which Requires Very High Ratio of Nitrogen content in Soil: ['cotton']
# Crops Which Requires Very High Ratio of Phosphorus content in Soil: ['grapes' 'apple']
# Crops Which Requires Very High Ratio of Pottasium content in Soil: ['grapes' 'apple']
# Crops Which Requires Very High Ratio of Rainfall content in Soil: ['rice' 'papaya' 'coconut']
# Crops Which Requires Very low Temprature: ['grapes']
# Crops Which Requires Very High Temprature: ['grapes' 'papaya']
# Crops Which Requires Very low Humidity: ['chickpea' 'kidneybeans']
# Crops Which Requires Very low PH: ['mothbeans']
# Crops Which Requires Very High PH: ['mothbeans']

# %%
#crops grown as per seasons

print("Summer crops")
print(file[(file['temperature']>30)&(file['humidity']>50)]['label'].unique())
print("---------------------------------------------------")
print("Winter crops")
print(file[(file['temperature']<20)&(file['humidity']>30)]['label'].unique())
print("---------------------------------------------------")
print("Rainy crops")
print(file[(file['rainfall']>200)&(file['humidity']>30)]['label'].unique())
print("---------------------------------------------------")
# Out:
# Summer crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# ---------------------------------------------------
# Winter crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# ---------------------------------------------------
# Rainy crops
# ['rice' 'papaya' 'coconut']
# ---------------------------------------------------

# %%
#clusturing the crops data

from sklearn.cluster import KMeans
#importing the Warnings library to avoid warnings
import warnings
warnings.filterwarnings('ignore')

#Lets select the Spending Score, Annual Income Columns from the data.
x = file.loc[:,['N','P','K','temperature','humidity','ph','rainfall']].values

#checking the shape of x
print(x.shape)

#lets convert this data into Dataframe

x_data = pd.DataFrame(x)
x_data.head()
# Out:
# (2200, 7)
#       0     1     2          3          4         5           6
# 0  90.0  42.0  43.0  20.879744  82.002744  6.502985  202.935536
# 1  85.0  58.0  41.0  21.770462  80.319644  7.038096  226.655537
# 2  60.0  55.0  44.0  23.004459  82.320763  7.840207  263.964248
# 3  74.0  35.0  40.0  26.491096  80.158363  6.980401  242.864034
# 4  78.0  42.0  42.0  20.130175  81.604873  7.628473  262.717340

# %%
#determining the optimal number of cluster in the dataset

plt.rcParams['figure.figsize'] = (10,4)

wcss = []
for i in range(1,11):
    km = KMeans(n_clusters= i, init='k-means++', max_iter=300,n_init=10,random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)
    
#plotting the result
plt.plot(range(1,11),wcss)
plt.title("The Elbow Method",fontsize = 20)
plt.xlabel("No. of Cluster",fontsize = 12)
plt.ylabel("WCSS",fontsize = 12)
plt.show()

# %%
#performing KMeans algorithm to perform clustring
km = KMeans(n_clusters=4, init = 'k-means++',max_iter= 300,n_init = 10,random_state=0 )
y_means = km.fit_predict(x)

#finding out the result
a = file['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means,a],axis=1)
z = z.rename(columns = {0:'cluster'})

#checking cluster for each crops

print("Lets Check the Results after applying the KMeans clustering Analysis \n")
print("Crops in First Cluster:",z[z['cluster'] ==0 ]['label'].unique())
print("---------------------------------------------")

print("Crops in Second Cluster:",z[z['cluster'] ==1 ]['label'].unique())
print("---------------------------------------------")
print("Crops in Third Cluster:",z[z['cluster'] ==2 ]['label'].unique())
print("---------------------------------------------")
print("Crops in Fourth Cluster:",z[z['cluster'] ==3 ]['label'].unique())
# Out:
# Lets Check the Results after applying the KMeans clustering Analysis
#
# Crops in First Cluster: ['grapes' 'apple']
# ---------------------------------------------
# Crops in Second Cluster: ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ---------------------------------------------
# Crops in Third Cluster: ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# ---------------------------------------------
# Crops in Fourth Cluster: ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']

# %%
#spliting the data for predicting modelling

y = file['label']
x = file.drop(['label'],axis=1)

print("Shape of X ",x.shape)
print("Shape of Y ",y.shape)
# Out:
# Shape of X  (2200, 7)
# Shape of Y  (2200,)

# %%
#creating the sets for validation
from sklearn import model_selection

# %%
x_train,x_test,y_train,y_test = model_selection.train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print("Shape of X Train",x_train.shape)
print("Shape of X Test",x_test.shape)
print("Shape of Y Train",y_train.shape)
print("Shape of Y Test",y_test.shape)
# Out:
# Shape of X Train (1540, 7)
# Shape of X Test (660, 7)
# Shape of Y Train (1540,)
# Shape of Y Test (660,)

# %%
from sklearn.linear_model import LogisticRegression

#traning the algorithm for further prediction 
algorithm = LogisticRegression()
algorithm.fit(x_train,y_train)
y_pred = algorithm.predict(x_test)
train_prediction = algorithm.predict(x_train)
test_score = algorithm.score(x_test,y_test)
train_score = algorithm.score(x_train,y_train)
print("Prediction Based on Train Data:",train_prediction)
print("Test Score:",test_score)
print("Train Score:",train_score)
# Out:
# Prediction Based on Train Data: ['jute' 'watermelon' 'orange' ... 'blackgram' 'lentil' 'orange']
# Test Score: 0.95
# Train Score: 0.9720779220779221

# %%
from sklearn.metrics import classification_report

#printing the classification report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        28
#       banana       1.00      1.00      1.00        30
#    blackgram       0.84      0.87      0.86        31
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        26
#       coffee       1.00      1.00      1.00        29
#       cotton       0.84      0.96      0.90        28
#       grapes       1.00      1.00      1.00        30
#         jute       0.83      0.94      0.88        31
#  kidneybeans       0.96      1.00      0.98        26
#       lentil       0.91      0.91      0.91        22
#        maize       0.92      0.81      0.86        27
#        mango       1.00      1.00      1.00        28
#    mothbeans       0.81      0.81      0.81        36
#     mungbean       1.00      0.97      0.98        29
#    muskmelon       1.00      1.00      1.00        30
# ...

# %%
file.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# # Predicting Crop based on Self Requirement

# %%
prediction = algorithm.predict((np.array([[90,40,40,20,80,7,200]])))
print("The suggested Crop for Given Climatic conditon is :",prediction)
# Out:
# The suggested Crop for Given Climatic conditon is : ['rice']

# %%
prediction = algorithm.predict((np.array([[100,77,73,20,79,7,50]])))
print("The suggested Crop for Given Climatic conditon is :",prediction)
# Out:
# The suggested Crop for Given Climatic conditon is : ['banana']
